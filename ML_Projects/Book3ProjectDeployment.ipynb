# %% [markdown]
# ### Module Deployement by feeding the clean data which does not have any outliers

# %%
from Deployment import *

# %% [markdown]
# + This deployemnt mosule is saved as python file with .py extension. It has all the steps we did for preprocessing this data in compact code form. Hence we need to import it to avoid preprocessing everytime when we get new data.

# %%
model = absenteeism_model('model', 'scaler')

# %%
model.load_and_clean_data('Absenteeism_part1.csv')

# %%
model.predicted_outputs()
# Out:
#        ID  Reason_1  Reason_2  Reason_3  Reason_4  Month of absence  \
# 0    11.0         0         0         0         1               7.0
# 1    36.0         0         0         0         0               7.0
# 2     3.0         0         0         0         1               7.0
# 3     7.0         1         0         0         0               7.0
# 4    11.0         0         0         0         1               7.0
# 5     3.0         0         0         0         1               7.0
# 6    10.0         0         0         0         1               7.0
# 7    20.0         0         0         0         1               7.0
# 8    14.0         0         0         1         0               7.0
# 9     1.0         0         0         0         1               7.0
# 10   20.0         1         0         0         0               7.0
# 11   20.0         1         0         0         0               7.0
# 12   20.0         1         0         0         0               7.0
# ...

# %%
model.predicted_outputs().to_csv('Absenteeism_predictions.csv', index = False)

# %%
df=model.predicted_outputs()

# %%
df.columns
# Out:
# Index(['ID', 'Reason_1', 'Reason_2', 'Reason_3', 'Reason_4',
#        'Month of absence', 'Day of the week', 'Transportation expense',
#        'Distance from Residence to Work', 'Service time', 'Age',
#        'Work load Average/day ', 'Hit target', 'Disciplinary failure',
#        'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight',
#        'Body mass index', 'Probability', 'Prediction'],
#       dtype='object')

# %%
df1=df[['ID','Prediction','Month of absence','Day of the week','Probability','Reason_1','Reason_2','Reason_3']]

# %%
df1.to_csv('FinalPredictions', index = False)

# %%
df2=pd.read_csv('FinalPredictions')

# %%
df2
# We created this dataframe for evaluation of each employee on basis of Reasons, Month of absence, Day of the week . 
#To see the predictions for them individually
# Out:
#        ID  Prediction  Month of absence  Day of the week  Probability  \
# 0    11.0           1               7.0              3.0     0.611031
# 1    36.0           0               7.0              3.0     0.001470
# 2     3.0           0               7.0              4.0     0.253006
# 3     7.0           1               7.0              5.0     0.978064
# 4    11.0           1               7.0              5.0     0.550065
# 5     3.0           0               7.0              6.0     0.208604
# 6    10.0           1               7.0              6.0     0.573487
# 7    20.0           1               7.0              6.0     0.702704
# 8    14.0           1               7.0              2.0     0.925259
# 9     1.0           0               7.0              2.0     0.476669
# 10   20.0           1               7.0              2.0     0.964078
# 11   20.0           1               7.0              3.0     0.959475
# ...

# %%
df2=df2.rename({'Month of absence':'Month','Day of the week':'WeekDay'},axis='columns')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ID = int(input("Enter ID between 1 to 36 : "))
Month= int(input("Enter Month between 1 to 12 : "))
df2=df2.loc[(df2.ID ==ID)]
df2=df2.loc[(df2.Month ==Month)]
df2
# Out:
# Enter ID between 1 to 36 : 11
# Enter Month between 1 to 12 : 7
#        ID  Prediction  Month  WeekDay  Probability  Reason_1  Reason_2  \
# 0    11.0           1    7.0      3.0     0.611031         0         0
# 4    11.0           1    7.0      5.0     0.550065         0         0
# 247  11.0           1    7.0      4.0     0.542481         0         0
# 249  11.0           1    7.0      2.0     0.930210         0         0
# 250  11.0           1    7.0      5.0     0.901486         0         0
# 475  11.0           1    7.0      2.0     0.663828         0         0
# 735  11.0           1    7.0      3.0     0.911575         1         0
#
#      Reason_3
# 0           0
# 4           0
# 247         0
# 249         1
# 250         1
# 475         0
# 735         0

# %% [markdown]
# + The above small code helps to analyse absentee of each employee individually
# + The dataset we used is supposed to be collection for three years. The deatils of 36 employees is given in this dataset for three years.
# + So it happens to give duplicate data for some ID's like data with prediction for same 'month' and same 'day of the week' twice as we can see in code above as the 'Year' column is not given in dataset
# + So we decided to use max method to decide which employess are predicted to be absent and which are not

# %%
ID1= df.groupby('ID')
ID1['Prediction'].max()
# Out:
# ID
# 1.0     1
# 2.0     1
# 3.0     1
# 4.0     0
# 5.0     1
# 6.0     1
# 7.0     1
# 8.0     1
# 9.0     1
# 10.0    1
# 11.0    1
# 12.0    1
# 13.0    1
# 14.0    1
# 15.0    1
# 16.0    1
# 17.0    1
# 18.0    1
# 19.0    1
# 20.0    1
# 21.0    1
# 22.0    1
# 23.0    1
# 24.0    1
# 25.0    1
# 26.0    1
# 27.0    1
# 28.0    1
# 29.0    1
# 30.0    1
# 31.0    1
# 32.0    1
# 33.0    1
# 34.0    1
# 35.0    0
# 36.0    1
# Name: Prediction, dtype: int32

# %% [markdown]
# + So by implementing above max method we can see that ID numbers 35 and 4 are predicted not to be absent while remaining ID's are predicted to be absent in future.

# %% [markdown]
# ### Predictions and Observations made from plots and dataset evaluation:-

# %%
g1=sns.scatterplot(x="Age",y="Probability",data=df)

# %% [markdown]
# 1. Most of the employees are below age 45 and remain more absent than employees with age above 45

# %%
g2=sns.regplot(x="Transportation expense",y="Probability",data=df)

# %% [markdown]
# 2. The above plot shows that the higher the transportation expense, higher is the probability to remain away from work

# %%
g3=sns.scatterplot(x="Reason_1",y="Probability",data=df)

# %%
g4=sns.scatterplot(x="Reason_2",y="Probability",data=df)

# %%
g5=sns.scatterplot(x="Reason_3",y="Probability",data=df)

# %%
g6=sns.scatterplot(x="Reason_4",y="Probability",data=df)

# %% [markdown]
# 2. The predections from above reason plots infer that most employees remain absent by usimg reason 1 and reason 4.
#
# Reason 1 category includes diseases that are serious in nature, while reason 4 includes category of routine checkup and appointments.

# %%
g7=sns.catplot(x="Social smoker",y="Probability",kind='bar',data=df)
g7.fig.set_size_inches(4,2)
g8=sns.catplot(x="Social drinker",y="Probability",kind='bar',data=df)
g8.fig.set_size_inches(4,2)
g9=sns.catplot(x="Education",y="Probability",kind='bar',data=df)
g9.fig.set_size_inches(5,5)

# %% [markdown]
# 3. Frove above plots it is seen that employees who are social smoker and drinker tend to be more basent in comparison with non-smoker and non-drinker
# 4. It is predicted that employees with high school degree tend to reamin more absent that the employees with higher degree

# %%
g5=sns.scatterplot(x="Son",y="Probability",data=df)

# %% [markdown]
# 5. Above plot shows that employess with 0,1 and 2 childrens are more absent in compoarison with employees having 3 and 4 childrens

# %% [markdown]
# ### Measures need to be taken by company from above observations :-
#
# Necessary measures needed to be taken from predictions
#
# 1.Employees with age below 45 are predicted to reamin more absent as compared to employees with age above 45.
#
# Measures :-
# + So from above observation, company should implement activities which would encourage there employees
#
# 2.The predections infer that most employees remain absent by usimg reason 1 and reason 4.
#
# Reason 1 category includes diseases that are serious in nature, while reason 4 includes category of routine checkup and appointments.
#
# Measures :-
# + From above observations disease of the musculoskeletal system and connective tissue is caused by bad posture while working.
# + So comapany should arrange workshops or health seminars so that employees will know how ergonomics is important to follow to keep yourself fit.
# + Also to avoid other diseaes related to digestive, circulatory and other diseases company should have gym in campuses so that employees will continue their excercise routine during extra work hours.
# + While for reason 4, company can arrange routine dental checkups and other routine checkups on company campuse itself. this might reduce the number of absentee due to this reason.
#
# 3.It is predicted that employees with high school degree tend to reamin more absent that the employees with higher degree,
#
# Measures:-
# + For this the company can motivate their employees to do further education by providing financial aid from company side
#
# 4.employees who are social smoker and drinker tend to be more basent in comparison with non-smoker and non-drinker
#
# Measures:-
# + People who tend to be social drinkers tend to be more absent than those who don’t drink. So company can keep a track of those people and inform those employees to reduce the intake of alcohol and smoking during working days and aslo provide some therapy sessions

# %% [markdown]
# ### Conclusion
#
# 1.By comparing accuracys of various machine learning algorithm we see that Random Forest and Logistic Regression models are good fit to work on this data.
#
# 2.Also this dataset doesnt provide adequate information needed for prediction. As, the 'Year' & 'Date' attribute is missing. We think that data of employee from particular year might help to predict truly whether the employee will remain absent or not.
#
# 3.The necessity of "Year" and "Date" attribute was felt because, when we analysed a particular ID to predict its absence multiple data were generated. For example when we tried to analyse for ID 11 we got multiple data for Month '7' and Day of the Week '5' as shown in above code In[14].
#
# 4.Thus, it is not clear from the  data that exactly in which year the ID was absent. So for accurate comprehension above mentioned attributes should be present in the dataset
